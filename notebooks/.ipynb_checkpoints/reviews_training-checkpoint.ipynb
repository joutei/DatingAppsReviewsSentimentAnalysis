# %%
# !pip install hopsworks==4.1.3
# !pip install requests_cache
# !pip install retry_requests
# !pip install google_play_scraper
# Out:
# Collecting hopsworks==4.1.3
#   Downloading hopsworks-4.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting pyhumps==1.6.1 (from hopsworks==4.1.3)
#   Downloading pyhumps-1.6.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from hopsworks==4.1.3) (2.32.3)
# Collecting furl (from hopsworks==4.1.3)
#   Downloading furl-2.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting boto3 (from hopsworks==4.1.3)
#   Downloading boto3-1.35.95-py3-none-any.whl.metadata (6.7 kB)
# Collecting pandas<2.2.0 (from hopsworks==4.1.3)
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting pyjks (from hopsworks==4.1.3)
#   Downloading pyjks-20.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mock (from hopsworks==4.1.3)
#   Downloading mock-5.1.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting avro==1.11.3 (from hopsworks==4.1.3)
#   Downloading avro-1.11.3.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 10.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from hopsworks==4.1.3) (2.0.36)
# Collecting PyMySQL[rsa] (from hopsworks==4.1.3)
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from hopsworks==4.1.3) (5.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from hopsworks==4.1.3) (2024.10.0)
# Collecting retrying (from hopsworks==4.1.3)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting hopsworks_aiomysql==0.2.1 (from hopsworks_aiomysql[sa]==0.2.1->hopsworks==4.1.3)
#   Downloading hopsworks_aiomysql-0.2.1-py3-none-any.whl.metadata (11 kB)
# Collecting opensearch-py<=2.4.2,>=1.1.0 (from hopsworks==4.1.3)
#   Downloading opensearch_py-2.4.2-py2.py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from hopsworks==4.1.3) (4.67.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.49.1 in /usr/local/lib/python3.10/dist-packages (from hopsworks==4.1.3) (1.69.0)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.4 in /usr/local/lib/python3.10/dist-packages (from hopsworks==4.1.3) (4.25.5)
# Collecting sqlalchemy (from hopsworks==4.1.3)
#   Downloading SQLAlchemy-2.0.29-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: urllib3>=1.26.18 in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks==4.1.3) (2.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks==4.1.3) (1.17.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks==4.1.3) (2.8.2)
# Requirement already satisfied: certifi>=2022.12.07 in /usr/local/lib/python3.10/dist-packages (from opensearch-py<=2.4.2,>=1.1.0->hopsworks==4.1.3) (2024.12.14)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->hopsworks==4.1.3) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->hopsworks==4.1.3) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->hopsworks==4.1.3) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->hopsworks==4.1.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->hopsworks==4.1.3) (3.10)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->hopsworks==4.1.3) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->hopsworks==4.1.3) (3.1.1)
# Collecting botocore<1.36.0,>=1.35.95 (from boto3->hopsworks==4.1.3)
#   Downloading botocore-1.35.95-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->hopsworks==4.1.3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->hopsworks==4.1.3)
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting orderedmultidict>=1.0.1 (from furl->hopsworks==4.1.3)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting javaobj-py3 (from pyjks->hopsworks==4.1.3)
#   Downloading javaobj_py3-0.4.4-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyasn1>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks==4.1.3) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from pyjks->hopsworks==4.1.3) (0.4.1)
# Collecting pycryptodomex (from pyjks->hopsworks==4.1.3)
#   Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting twofish (from pyjks->hopsworks==4.1.3)
#   Downloading twofish-0.3.0.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (from PyMySQL[rsa]->hopsworks==4.1.3) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography->PyMySQL[rsa]->hopsworks==4.1.3) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography->PyMySQL[rsa]->hopsworks==4.1.3) (2.22)
# Downloading hopsworks-4.1.3-py3-none-any.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.1/640.1 kB 45.4 MB/s eta 0:00:00
# Downloading hopsworks_aiomysql-0.2.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 4.5 MB/s eta 0:00:00
# Downloading pyhumps-1.6.1-py3-none-any.whl (5.0 kB)
# Downloading opensearch_py-2.4.2-py2.py3-none-any.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.6/258.6 kB 25.8 MB/s eta 0:00:00
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 116.0 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.29-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.6 MB/s eta 0:00:00
# Downloading boto3-1.35.95-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 16.3 MB/s eta 0:00:00
# Downloading furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Downloading mock-5.1.0-py3-none-any.whl (30 kB)
# Downloading pyjks-20.0.0-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 4.6 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading botocore-1.35.95-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 112.0 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.5 MB/s eta 0:00:00
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 9.5 MB/s eta 0:00:00
# Downloading javaobj_py3-0.4.4-py2.py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 6.7 MB/s eta 0:00:00
# Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 89.4 MB/s eta 0:00:00
# Building wheels for collected packages: avro, twofish
#   Building wheel for avro (pyproject.toml) ... done
#   Created wheel for avro: filename=avro-1.11.3-py2.py3-none-any.whl size=123913 sha256=fb6474e2bde960299d7e7a5267f06411fdbf1b4e18ac360f90581b6a84a7896e
#   Stored in directory: /root/.cache/pip/wheels/1d/f6/41/0e0399396af07060e64d4e32c8bd259b48b98a4a114df31294
#   Building wheel for twofish (setup.py) ... done
#   Created wheel for twofish: filename=twofish-0.3.0-cp310-cp310-linux_x86_64.whl size=24199 sha256=22e5326412d8a738a8eb91c05c9571a84e85135669af4421be2a324f46d50add
#   Stored in directory: /root/.cache/pip/wheels/a7/3c/27/c390be4f3e8a299d4b2836f8daa19697eb991eacbfabe25031
# Successfully built avro twofish
# Installing collected packages: twofish, pyhumps, javaobj-py3, sqlalchemy, retrying, PyMySQL, pycryptodomex, orderedmultidict, mock, jmespath, avro, pyjks, pandas, opensearch-py, hopsworks_aiomysql, furl, botocore, s3transfer, boto3, hopsworks
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# Successfully installed PyMySQL-1.1.1 avro-1.11.3 boto3-1.35.95 botocore-1.35.95 furl-2.1.3 hopsworks-4.1.3 hopsworks_aiomysql-0.2.1 javaobj-py3-0.4.4 jmespath-1.0.1 mock-5.1.0 opensearch-py-2.4.2 orderedmultidict-1.0.1 pandas-2.1.4 pycryptodomex-3.21.0 pyhumps-1.6.1 pyjks-20.0.0 retrying-1.3.4 s3transfer-0.10.4 sqlalchemy-2.0.29 twofish-0.3.0
# Collecting requests_cache
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests_cache) (24.3.0)
# Collecting cattrs>=22.2 (from requests_cache)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests_cache) (4.3.6)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.10/dist-packages (from requests_cache) (2.32.3)
# Collecting url-normalize>=1.4 (from requests_cache)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.10/dist-packages (from requests_cache) (2.3.0)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests_cache) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests_cache) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests_cache) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests_cache) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests_cache) (2024.12.14)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests_cache) (1.17.0)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 6.6 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.6 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests_cache
# Successfully installed cattrs-24.1.2 requests_cache-1.2.1 url-normalize-1.4.3
# Collecting retry_requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from retry_requests) (2.32.3)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.10/dist-packages (from retry_requests) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->retry_requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->retry_requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->retry_requests) (2024.12.14)
# Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: retry_requests
# Successfully installed retry_requests-2.0.0
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.0 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
import datetime
import time
import requests
import pandas as pd
import hopsworks
import util
import json
import os
import warnings
warnings.filterwarnings("ignore")

# %%
os.environ["HOPSWORKS_API_KEY"] = "6xLHrUPek6nw9STy.ueYbHCnUwYhFQ5xzscRiONFQ4ZmgUxMFUt8bnCu3UX69ejYcaIxeUHynvrMhcrt5"

project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1185941

# %%
reviews_fg = fs.get_feature_group(
    name='reviews',
    version=1,
)

# %%
df = reviews_fg.read()
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (3.44s)

# %%
df
# Out:
#                                    reviewid  \
# 0      ed92cde4-7c1d-4011-b229-c60df1f034fa
# 1      3e3bd196-9c70-413e-bcf6-1763782842cc
# 2      3c16071f-2e1a-4302-af87-4e3b274f6e71
# 3      f59582e9-ebb0-4527-83d3-7de98c38ea40
# 4      459e063c-e782-4cdb-a960-85fa4394dacc
# ...                                     ...
# 29989  067098b1-0d69-43a5-a196-fc43a0bfd89b
# 29990  bcde5e68-c34f-43d1-9d9b-c4d127228245
# 29991  623dd1a3-3feb-47be-a219-42faa649a5a1
# 29992  da147881-9479-4246-9784-9dedcb2bb516
# 29993  2a212b6a-3f56-45d0-8434-35b1d14154b2
#
#                                                  content  score  \
# 0                  Won't allow me to delete the account.      1
# 1                                                   nice      5
# 2                                                   good      5
# 3      use better hinge, tinder anymore nothing in Ge...      1
# 4                                                   good      5
# ...                                                  ...    ...
# 29989                it's good , i wish the app wAs free      5
# 29990                                               none      4
# 29991                                         it's great      5
# 29992  Locked me out of my own account, forced a phot...      1
# 29993                                               nice      5
#
#                              at  thumbsupcount  \
# 0     2024-07-16 09:30:12+00:00              1
# 1     2024-07-11 01:09:44+00:00              0
# 2     2024-07-06 23:20:29+00:00              0
# 3     2024-09-13 12:40:36+00:00              1
# 4     2024-10-24 21:30:28+00:00              0
# ...                         ...            ...
# 29989 2024-07-12 14:12:47+00:00              0
# 29990 2024-12-07 00:32:24+00:00              0
# 29991 2024-12-28 14:47:25+00:00              0
# 29992 2024-10-22 23:48:45+00:00              0
# 29993 2024-06-22 16:07:35+00:00              0
#
#                                        augmented_comment sentiment
# 0      Won't allow me to delete the account.. Score g...  positive
# 1           nice. Score given on a scale of 1 to 5 is: 5  positive
# 2           good. Score given on a scale of 1 to 5 is: 5  positive
# 3      use better hinge, tinder anymore nothing in Ge...  positive
# 4           good. Score given on a scale of 1 to 5 is: 5  positive
# ...                                                  ...       ...
# 29989  it's good , i wish the app wAs free. Score giv...  positive
# 29990       none. Score given on a scale of 1 to 5 is: 4   neutral
# 29991  it's great. Score given on a scale of 1 to 5 i...  positive
# 29992  Locked me out of my own account, forced a phot...  negative
# 29993       nice. Score given on a scale of 1 to 5 is: 5  positive
#
# [29994 rows x 7 columns]

# %% [markdown]
# # Preprocessing the data

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
import re
import warnings
warnings.filterwarnings('ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29994 entries, 0 to 29993
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   reviewid           29994 non-null  object
#  1   content            29994 non-null  object
#  2   score              29994 non-null  int64
#  3   at                 29994 non-null  datetime64[us, Etc/UTC]
#  4   thumbsupcount      29994 non-null  int64
#  5   augmented_comment  29994 non-null  object
#  6   sentiment          29994 non-null  object
# dtypes: datetime64[us, Etc/UTC](1), int64(2), object(4)
# memory usage: 1.6+ MB

# %%
# Reformatting columns
df['augmented_comment'] = df['augmented_comment'].astype(str)  # Convert 'augmented_comment' to string
df['sentiment'] = df['sentiment'].astype(str)  # Convert 'sentiment' to string
df['content'] = df['content'].astype(str)  # Convert 'content' to string

# %%
df = df[['sentiment','content', 'score']]

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    15035
# negative    11979
# neutral      2980
# Name: count, dtype: int64

# %%
# Drop rows where sentiment is 'neutral'
df = df[df['sentiment'] != 'neutral']

# Map 'positive' to 1 and 'negative' to 0
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})

# Verify the changes
df['sentiment'].value_counts()
# Out:
# sentiment
# 1    15035
# 0    11979
# Name: count, dtype: int64

# %%
import nltk
nltk.download('stopwords')
## remove stopwords and punctuation marks
stuff_to_be_removed = list(stopwords.words('english'))+list(punctuation)

corpus = df['content'].tolist()
print(len(corpus))
print(corpus[0])
# Out:
# 27014
# Won't allow me to delete the account.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# %%time
nltk.download('wordnet')
final_corpus = []
final_corpus_joined = []
for i in df.index:

    text = re.sub('[^a-zA-Z]', ' ', df['content'][i])
    #Convert to lowercase
    text = text.lower()

    ##Convert to list from string
    text = text.split()

    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text
            if not word in stuff_to_be_removed]
    text1 = " ".join(text)
    final_corpus.append(text)
    final_corpus_joined.append(text1)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# CPU times: user 6.29 s, sys: 113 ms, total: 6.41 s
# Wall time: 6.39 s

# %%
data_cleaned = pd.DataFrame()
data_cleaned["content"] = final_corpus_joined
data_cleaned["sentiment"] = df["sentiment"].values

# %%
data_eda = pd.DataFrame()
data_eda['content'] = final_corpus
data_eda['sentiment'] = df["sentiment"].values

# Storing positive data seperately
positive = data_eda[data_eda['sentiment'] == 1]
positive_list = positive['content'].tolist()

# Storing negative data seperately
negative = data_eda[data_eda['sentiment'] == 0]
negative_list = negative['content'].tolist()

positive_all = " ".join([word for sent in positive_list for word in sent ])
negative_all = " ".join([word for sent in negative_list for word in sent ])

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(positive_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud)
plt.title("Positive")
plt.show()

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(negative_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud)
plt.title("negative")
plt.show()

# %% [markdown]
# Inference:
#
# - Positive data has words like Thank, love , LOL, Haha ets
# - Negative data has words like work, sad, tired, suck sorry
# Some of the words are still common in both such as Lol, quot

# %%
def get_count(data):
    dic = {}
    for i in data:
        for j in i:
            if j not in dic:
                dic[j]=1
            else:
                dic[j]+=1

    return(dic)
count_corpus = get_count(positive_list)

# %%
count_corpus = pd.DataFrame({"word":count_corpus.keys(),"count":count_corpus.values()})
count_corpus = count_corpus.sort_values(by = "count", ascending = False)

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x = count_corpus["word"][:20], y = count_corpus["count"][:20])
plt.title('one words in positive data')
plt.show()

# %%
def get_count(data):
    dic = {}
    for i in data:
        for j in i:
            if j not in dic:
                dic[j]=1
            else:
                dic[j]+=1

    #dic = dict(sorted(dic.items() , key = lambda x:x[1],reverse=True))
    return(dic)
count_corpus = get_count(negative_list)

# %%
count_corpus = pd.DataFrame({"word":count_corpus.keys(),"count":count_corpus.values()})
count_corpus = count_corpus.sort_values(by = "count", ascending = False)

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x = count_corpus["word"][:20], y = count_corpus["count"][:20])
plt.title('one words in negative data')
plt.show()

# %% [markdown]
# Inference
# - Positive data has words like match, great, love, best
# - Negative data has words like fake, banned, scam etc

# %% [markdown]
# # Naive Bayes

# %%
def get_tokens_for_model(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tokens)

positive_tokens_for_model = get_tokens_for_model(positive_list)
negative_tokens_for_model = get_tokens_for_model(negative_list)

# %%
import random

positive_dataset = [(review_dict, "Positive")
                     for review_dict in positive_tokens_for_model]

negative_dataset = [(review_dict, "Negative")
                     for review_dict in negative_tokens_for_model]
dataset = positive_dataset + negative_dataset

random.shuffle(dataset)
# Out:
# [({'bad': True}, 'Negative'),
#  ({'many': True, 'scammer': True}, 'Negative'),
#  ({'many': True,
#    'fake': True,
#    'account': True,
#    'expensive': True,
#    'tailored': True,
#    'men': True},
#   'Negative'),
#  ({'instagram': True, 'follower': True, 'finding': True, 'app': True},
#   'Positive'),
#  ({'getting': True,
#    'suck': True,
#    'install': True,
#    'screen': True,
#    'said': True,
#    'thank': True,
#    'account': True,
#    'review': True,
#    'take': True,
#    'long': True,
#    'time': True,
#    'snack': True,
#    'almost': True,
#    'year': True,
#    'since': True},
#   'Negative'),
#  ({'app': True,
#    'filled': True,
#    'bot': True,
#    'point': True,
#    'every': True,
#    'time': True,
#    'match': True,
#    'someone': True,
#    'expecting': True,
#    'spot': True,
#    'profile': True,
#    'within': True,
#    'ten': True,
#    'second': True,
#    'used': True,
#    'good': True,
#    'got': True,
#    'back': True,
#    'month': True,
#    'went': True,
#    'downhill': True},
#   'Positive'),
#  ({'great': True}, 'Positive'),
#  ({'started': True,
#    'using': True,
#    'app': True,
#    'slow': True,
#    'af': True,
#    'work': True,
#    'correctly': True,
#    'time': True},
#   'Negative'),
#  ({'great': True}, 'Positive'),
#  ({'expensive': True}, 'Positive'),
#  ({'people': True, 'fast': True, 'food': True}, 'Positive'),
#  ({'buggy': True, 'app': True, 'lot': True, 'error': True}, 'Negative'),
#  ({'nice': True, 'app': True}, 'Positive'),
#  ({'social': True,
#    'medium': True,
#    'handle': True,
#    'profile': True,
#    'put': True,
#    'effort': True,
#    'bio': True,
#    'keep': True,
#    'removing': True,
#    'nothing': True,
#    'right': True,
#    'spent': True,
#    'money': True,
#    'app': True,
#    'never': True,
#    'working': True,
#    'bad': True,
#    'developer': True},
#   'Negative'),
#  ({'enjoy': True,
#    'ease': True,
#    'using': True,
#    'tinder': True,
#    'extra': True,
#    'charge': True,
#    'option': True,
#    'irritating': True},
#   'Negative'),
#  ({'human': True,
#    'verification': True,
#    'suck': True,
#    'long': True,
#    'mean': True,
#    'tired': True,
#    'solve': True,
#    'math': True,
#    'thing': True,
#    'start': True,
#    'hearing': True,
#    'footstep': True},
#   'Negative'),
#  ({'app': True,
#    'work': True,
#    'around': True,
#    'middleman': True,
#    'sole': True,
#    'bidding': True,
#    'smart': True,
#    'enough': True,
#    'analyze': True,
#    'picture': True,
#    'like': True,
#    'pool': True,
#    'second': True,
#    'swipe': True,
#    'always': True,
#    'someone': True,
#    'swiped': True,
#    'right': True,
#    'refresh': True,
#    'everytime': True,
#    'save': True,
#    'day': True,
#    'maybe': True,
#    'even': True,
#    'week': True,
#    'worth': True,
#    'time': True,
#    'constantly': True,
#    'rummage': True,
#    'boring': True,
#    'people': True,
#    'bot': True,
#    'good': True,
#    'luck': True,
#    'tinder': True,
#    'confident': True,
#    'learn': True,
#    'everyone': True,
#    'flaw': True,
#    'accept': True},
#   'Positive'),
#  ({'see': True,
#    'banned': True,
#    'try': True,
#    'tinder': True,
#    'never': True,
#    'much': True,
#    'lol': True},
#   'Negative'),
#  ({'deleted': True,
#    'account': True,
#    'plus': True,
#    'made': True,
#    'new': True,
#    'one': True,
#    'gold': True,
#    'working': True,
#    'profile': True,
#    'keep': True,
#    'showing': True,
#    'matter': True,
#    'many': True,
#    'time': True,
#    'swipe': True,
#    'left': True,
#    'right': True,
#    'actually': True,
#    'able': True,
#    'get': True,
#    'match': True,
#    'way': True,
#    'contact': True,
#    'app': True,
#    'going': True,
#    'day': True,
#    'emailed': True,
#    'last': True,
#    'heard': True,
#    'anything': True,
#    'back': True,
#    'would': True,
#    'give': True,
#    'zero': True,
#    'star': True,
#    'possible': True},
#   'Negative'),
#  ({'tinder': True, 'cutie': True, 'user': True, 'friendly': True}, 'Positive'),
#  ({'app': True,
#    'show': True,
#    'account': True,
#    'nowhere': True,
#    'nearby': True,
#    'lying': True,
#    'distance': True,
#    'full': True,
#    'fake': True,
#    'people': True,
#    'promoting': True,
#    'instagram': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'much': True, 'money': True}, 'Positive'),
#  ({'app': True,
#    'wrong': True,
#    'society': True,
#    'dating': True,
#    'apps': True,
#    'superficial': True,
#    'tinder': True,
#    'seems': True,
#    'pander': True,
#    'concept': True,
#    'sickens': True,
#    'shallow': True,
#    'people': True,
#    'become': True,
#    'also': True,
#    'annoying': True,
#    'message': True,
#    'forced': True,
#    'limited': True,
#    'way': True,
#    'see': True,
#    'text': True,
#    'box': True,
#    'know': True,
#    'actually': True,
#    'typing': True,
#    'pretty': True,
#    'much': True,
#    'type': True,
#    'hello': True,
#    'tried': True,
#    'minimize': True,
#    'keyboard': True,
#    'ended': True,
#    'losing': True,
#    'match': True,
#    'pay': True,
#    'find': True,
#    'money': True,
#    'grabber': True},
#   'Negative'),
#  ({'unable': True,
#    'log': True,
#    'wasted': True,
#    'subscription': True,
#    'fee': True},
#   'Negative'),
#  ({'okay': True, 'pay': True, 'see': True, 'like': True, 'reply': True},
#   'Positive'),
#  ({'bad': True, 'app': True}, 'Negative'),
#  ({'middle': True,
#    'talking': True,
#    'someone': True,
#    'account': True,
#    'went': True,
#    'review': True,
#    'emailed': True,
#    'asked': True,
#    'back': True,
#    'give': True,
#    'refund': True,
#    'reading': True,
#    'google': True,
#    'see': True,
#    'tinder': True,
#    'notorious': True,
#    'honestly': True,
#    'would': True,
#    'recommend': True,
#    'dating': True,
#    'apps': True},
#   'Positive'),
#  ({'buy': True,
#    'subscription': True,
#    'like': True,
#    'given': True,
#    'first': True,
#    'sign': True,
#    'real': True,
#    'pulled': True,
#    'subscribe': True,
#    'week': True,
#    'find': True,
#    'people': True,
#    'liked': True,
#    'actually': True,
#    'mile': True,
#    'away': True,
#    'simply': True,
#    'going': True,
#    'work': True,
#    'serious': True,
#    'relationship': True,
#    'even': True,
#    'quick': True,
#    'fling': True,
#    'ended': True,
#    'morning': True,
#    'ran': True,
#    'use': True,
#    'free': True,
#    'version': True,
#    'pray': True,
#    'earth': True,
#    'match': True,
#    'want': True,
#    'talk': True},
#   'Negative'),
#  ({'connect': True, 'world': True}, 'Positive'),
#  ({'since': True,
#    'last': True,
#    'week': True,
#    'full': True,
#    'obviously': True,
#    'fake': True,
#    'bot': True,
#    'profile': True,
#    'ai': True,
#    'art': True,
#    'face': True,
#    'distance': True,
#    'ignores': True,
#    'app': True,
#    'filter': True,
#    'uninstalled': True},
#   'Negative'),
#  ({'wonderful': True, 'app': True}, 'Positive'),
#  ({'meh': True,
#    'people': True,
#    'flakey': True,
#    'app': True,
#    'expensive': True},
#   'Negative'),
#  ({'wow': True, 'app': True, 'awesome': True}, 'Positive'),
#  ({'nice': True, 'meet': True}, 'Positive'),
#  ({'expensive': True}, 'Positive'),
#  ({'worst': True,
#    'app': True,
#    'ever': True,
#    'hey': True,
#    'need': True,
#    'verify': True,
#    'human': True,
#    'time': True,
#    'never': True,
#    'use': True,
#    'pay': True,
#    'month': True,
#    'rip': True},
#   'Negative'),
#  ({'wow': True}, 'Positive'),
#  ({'good': True, 'app': True}, 'Positive'),
#  ({'fake': True,
#    'flake': True,
#    'filter': True,
#    'worth': True,
#    'energy': True,
#    'swipe': True},
#   'Negative'),
#  ({'want': True,
#    'piss': True,
#    'away': True,
#    'money': True,
#    'app': True,
#    'match': True,
#    'ever': True,
#    'constantly': True,
#    'try': True,
#    'get': True,
#    'upgrade': True,
#    'kind': True,
#    'bot': True,
#    'fake': True,
#    'profile': True,
#    'total': True,
#    'trash': True},
#   'Positive'),
#  ({'nice': True}, 'Positive'),
#  ({'nice': True}, 'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'costy': True,
#    'unnecessary': True,
#    'fee': True,
#    'let': True,
#    'app': True,
#    'run': True,
#    'free': True,
#    'least': True,
#    'like': True,
#    'message': True,
#    'profile': True,
#    'view': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'garbage': True,
#    'app': True,
#    'support': True,
#    'everything': True,
#    'riddled': True,
#    'bot': True,
#    'ad': True,
#    'temporarily': True,
#    'overseas': True,
#    'quit': True,
#    'using': True,
#    'getting': True,
#    'back': True,
#    'trying': True,
#    'log': True,
#    'found': True,
#    'account': True,
#    'banned': True,
#    'sheet': True,
#    'multiple': True,
#    'time': True,
#    'reaching': True,
#    'tell': True,
#    'anything': True,
#    'get': True,
#    'copy': True,
#    'pasted': True,
#    'response': True,
#    'great': True,
#    'match': True,
#    'guess': True,
#    'decide': True,
#    'delete': True,
#    'seemingly': True,
#    'reason': True,
#    'good': True,
#    'riddance': True},
#   'Negative'),
#  ({'logged': True,
#    'find': True,
#    'chat': True,
#    'match': True,
#    'cleared': True,
#    'budding': True,
#    'bond': True,
#    'friendship': True,
#    'gone': True,
#    'like': True,
#    'mad': True,
#    'absolutely': True,
#    'horrid': True,
#    'app': True},
#   'Negative'),
#  ({'say': True,
#    'someone': True,
#    'like': True,
#    'mile': True,
#    'away': True,
#    'change': True,
#    'setting': True,
#    'max': True,
#    'get': True,
#    'people': True,
#    'see': True},
#   'Positive'),
#  ({'using': True,
#    'lately': True,
#    'message': True,
#    'match': True,
#    'show': True,
#    'people': True,
#    'told': True,
#    'sent': True,
#    'screenshots': True,
#    'messaging': True,
#    'tried': True,
#    'reinstall': True,
#    'ing': True,
#    'still': True,
#    'nothing': True},
#   'Negative'),
#  ({'tooo': True, 'expensive': True}, 'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'week': True,
#    'catfishing': True,
#    'bot': True,
#    'hard': True,
#    'drug': True,
#    'addict': True,
#    'free': True,
#    'side': True,
#    'offer': True,
#    'nothing': True,
#    'app': True,
#    'used': True,
#    'bad': True,
#    'definitely': True,
#    'worth': True,
#    'downloading': True},
#   'Negative'),
#  ({'wish': True, 'could': True, 'give': True, 'less': True}, 'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'like': True}, 'Positive'),
#  ({'super': True}, 'Positive'),
#  ({'please': True,
#    'provide': True,
#    'sorting': True,
#    'based': True,
#    'distance': True,
#    'option': True},
#   'Positive'),
#  ({'please': True,
#    'trying': True,
#    'delete': True,
#    'tinder': True,
#    'message': True,
#    'match': True,
#    'keep': True,
#    'saying': True,
#    'fail': True,
#    'help': True,
#    'account': True,
#    'work': True,
#    'anymore': True,
#    'swipe': True,
#    'month': True},
#   'Negative'),
#  ({'spend': True,
#    'fake': True,
#    'profile': True,
#    'see': True,
#    'like': True,
#    'message': True,
#    'app': True,
#    'huge': True,
#    'waste': True,
#    'time': True,
#    'super': True,
#    'person': True,
#    'platnum': True,
#    'view': True,
#    'scam': True},
#   'Negative'),
#  ({'thanks': True, 'tinder': True}, 'Positive'),
#  ({'used': True,
#    'decent': True,
#    'app': True,
#    'meeting': True,
#    'people': True,
#    'oct': True,
#    'encountered': True,
#    'issue': True,
#    'account': True,
#    'sending': True,
#    'receiving': True,
#    'message': True,
#    'blue': True,
#    'middle': True,
#    'setting': True,
#    'date': True,
#    'guy': True,
#    'reached': True,
#    'customer': True,
#    'support': True,
#    'gave': True,
#    'response': True,
#    'getting': True,
#    'escalated': True,
#    'adeline': True,
#    'help': True,
#    'since': True,
#    'silence': True,
#    'even': True,
#    'asking': True,
#    'status': True,
#    'update': True,
#    'every': True,
#    'day': True,
#    'past': True,
#    'week': True,
#    'heck': True,
#    'kind': True,
#    'service': True,
#    'switched': True,
#    'hinge': True},
#   'Negative'),
#  ({'took': True,
#    'subscription': True,
#    'everything': True,
#    'normal': True,
#    'swipe': True,
#    'right': True,
#    'left': True,
#    'one': True,
#    'platinum': True,
#    'month': True,
#    'gold': True,
#    'gone': True,
#    'didnt': True,
#    'recharged': True,
#    'thing': True,
#    'like': True,
#    'see': True,
#    'mean': True,
#    'tinder': True,
#    'focused': True,
#    'money': True,
#    'sorry': True,
#    'uninstalling': True,
#    'thanks': True,
#    'making': True,
#    'believe': True,
#    'dating': True,
#    'apps': True,
#    'ever': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'bored': True, 'want': True, 'laugh': True, 'men': True}, 'Positive'),
#  ({'nice': True, 'app': True}, 'Positive'),
#  ({'expiring': True, 'match': True, 'gtfo': True, 'leaving': True},
#   'Positive'),
#  ({'best': True,
#    'app': True,
#    'meet': True,
#    'people': True,
#    'seems': True,
#    'like': True,
#    'gotta': True,
#    'pay': True,
#    'even': True,
#    'anything': True,
#    'add': True,
#    'interest': True,
#    'unless': True,
#    'get': True,
#    'gold': True},
#   'Positive'),
#  ({'love': True}, 'Positive'),
#  ({'okay': True}, 'Positive'),
#  ({'putting': True,
#    'actual': True,
#    'chat': True,
#    'match': True,
#    'pay': True,
#    'wall': True,
#    'make': True,
#    'app': True,
#    'unusable': True,
#    'horrible': True,
#    'evil': True,
#    'big': True,
#    'company': True,
#    'move': True,
#    'worst': True,
#    'thing': True,
#    'ever': True,
#    'happen': True,
#    'dating': True,
#    'much': True,
#    'finding': True,
#    'love': True},
#   'Negative'),
#  ({'poor': True, 'think': True, 'live': True, 'london': True}, 'Negative'),
#  ({'unblock': True, 'account': True}, 'Negative'),
#  ({'tinder': True,
#    'offered': True,
#    'gold': True,
#    'subscription': True,
#    'half': True,
#    'price': True,
#    'decided': True,
#    'try': True,
#    'one': True,
#    'like': True,
#    'due': True,
#    'boost': True,
#    'rest': True,
#    'month': True,
#    'moment': True,
#    'ran': True,
#    'received': True,
#    'two': True,
#    'seems': True,
#    'far': True,
#    'convenient': True,
#    'coincidence': True,
#    'greedy': True,
#    'predatory': True,
#    'avoid': True},
#   'Negative'),
#  ({'forced': True,
#    'biometric': True,
#    'face': True,
#    'thing': True,
#    'rolling': True,
#    'busted': True,
#    'af': True,
#    'tried': True,
#    'verifying': True,
#    'dozen': True,
#    'time': True,
#    'last': True,
#    'week': True,
#    'every': True,
#    'single': True,
#    'get': True,
#    'told': True,
#    'match': True,
#    'profile': True,
#    'photo': True,
#    'emailed': True,
#    'manipulated': True,
#    'way': True,
#    'yet': True,
#    'copy': True,
#    'paste': True,
#    'response': True,
#    'saying': True,
#    'need': True,
#    'verify': True,
#    'delete': True,
#    'account': True,
#    'either': True,
#    'force': True,
#    'screen': True,
#    'onto': True,
#    'skip': True,
#    'trash': True,
#    'fire': True,
#    'app': True,
#    'never': True,
#    'use': True},
#   'Negative'),
#  ({'best': True, 'trust': True}, 'Positive'),
#  ({'cannot': True,
#    'disable': True,
#    'ad': True,
#    'tinder': True,
#    'gold': True,
#    'whats': True,
#    'wrong': True},
#   'Negative'),
#  ({'fair': True,
#    'experience': True,
#    'checking': True,
#    'profile': True,
#    'user': True,
#    'friendly': True,
#    'application': True,
#    'yet': True,
#    'met': True,
#    'anyone': True,
#    'completed': True,
#    'also': True,
#    'tried': True,
#    'pair': True,
#    'membership': True,
#    'time': True,
#    'doubt': True,
#    'rad': True,
#    'thing': True,
#    'hear': True,
#    'friend': True,
#    'want': True,
#    'heard': True,
#    'easy': True,
#    'meet': True,
#    'people': True,
#    'using': True,
#    'platform': True,
#    'vain': True},
#   'Positive'),
#  ({'first': True,
#    'time': True,
#    'trying': True,
#    'app': True,
#    'match': True,
#    'make': True,
#    'payment': True,
#    'poor': True,
#    'service': True,
#    'tinder': True},
#   'Negative'),
#  ({'loosing': True,
#    'quality': True,
#    'charging': True,
#    'giving': True,
#    'little': True,
#    'return': True,
#    'higher': True,
#    'price': True},
#   'Positive'),
#  ({'tinder': True,
#    'dating': True,
#    'app': True,
#    'biased': True,
#    'far': True,
#    'representing': True,
#    'men': True,
#    'good': True,
#    'decent': True,
#    'really': True,
#    'trying': True,
#    'meet': True,
#    'woman': True,
#    'get': True,
#    'potential': True,
#    'match': True,
#    'local': True,
#    'kcmo': True,
#    'kck': True,
#    'pay': True,
#    'least': True,
#    'gold': True,
#    'membership': True,
#    'set': True,
#    'profile': True,
#    'free': True,
#    'level': True,
#    'setting': True,
#    'close': True,
#    'never': True,
#    'check': True,
#    'even': True,
#    'see': True,
#    'like': True,
#    'send': True,
#    'give': True},
#   'Negative'),
#  ({'account': True,
#    'review': True,
#    'reason': True,
#    'take': True,
#    'minute': True,
#    'hour': True,
#    'counting': True,
#    'notification': True,
#    'message': True,
#    'stupid': True,
#    'annoying': True,
#    'new': True,
#    'like': True,
#    'jealous': True,
#    'kid': True,
#    'app': True,
#    'think': True,
#    'iq': True,
#    'number': True,
#    'remains': True,
#    'even': True,
#    'remove': True,
#    'list': True,
#    'go': True},
#   'Negative'),
#  ({'think': True,
#    'need': True,
#    'verify': True,
#    'id': True,
#    'real': True,
#    'person': True,
#    'dealing': True,
#    'many': True,
#    'scammer': True,
#    'want': True,
#    'waste': True,
#    'time': True,
#    'like': True,
#    'would': True,
#    'pay': True,
#    'knowing': True,
#    'allowed': True,
#    'app': True,
#    'worse': True,
#    'ever': True},
#   'Negative'),
#  ({'boring': True}, 'Positive'),
#  ({'fake': True,
#    'account': True,
#    'heavy': True,
#    'monetization': True,
#    'exploitation': True,
#    'people': True,
#    'loneliness': True,
#    'getting': True,
#    'dopamine': True,
#    'relationship': True},
#   'Negative'),
#  ({'app': True,
#    'tinder': True,
#    'need': True,
#    'remove': True,
#    'play': True,
#    'store': True,
#    'scam': True,
#    'subscribe': True,
#    'every': True,
#    'thing': True,
#    'nothing': True,
#    'show': True},
#   'Negative'),
#  ({'tinder': True,
#    'keep': True,
#    'stopping': True,
#    'phone': True,
#    'finding': True,
#    'hard': True,
#    'open': True,
#    'uninstalled': True,
#    'stalled': True,
#    'back': True,
#    'several': True,
#    'time': True,
#    'yet': True,
#    'disturbing': True},
#   'Negative'),
#  ({'gold': True,
#    'hot': True,
#    'canceled': True,
#    'without': True,
#    'notice': True,
#    'get': True,
#    'touch': True,
#    'helped': True,
#    'supposed': True,
#    'renew': True,
#    'logged': True,
#    'two': True,
#    'day': True,
#    'ago': True,
#    'longer': True,
#    'pay': True,
#    'time': True,
#    'paying': True,
#    'absurd': True},
#   'Negative'),
#  ({'many': True, 'trans': True, 'people': True, 'messaging': True},
#   'Positive'),
#  ({'really': True,
#    'bad': True,
#    'gatekeeping': True,
#    'like': True,
#    'attractive': True,
#    'man': True,
#    'people': True,
#    'swipe': True,
#    'right': True,
#    'would': True,
#    'problem': True,
#    'person': True,
#    'lock': True,
#    'everything': True,
#    'behind': True,
#    'pay': True,
#    'wall': True,
#    'support': True,
#    'team': True,
#    'almost': True,
#    'nonexistent': True,
#    'download': True,
#    'different': True,
#    'app': True,
#    'also': True,
#    'owned': True,
#    'parent': True,
#    'company': True,
#    'see': True,
#    'talking': True},
#   'Negative'),
#  ({'bot': True,
#    'onlyfans': True,
#    'advertisement': True,
#    'ghosters': True,
#    'non': True,
#    'responder': True,
#    'real': True,
#    'people': True,
#    'weird': True,
#    'time': True,
#    'dude': True},
#   'Negative'),
#  ({'great': True, 'app': True}, 'Positive'),
#  ({'good': True, 'apos': True}, 'Positive'),
#  ({'terrible': True,
#    'app': True,
#    'unfortunate': True,
#    'new': True,
#    'change': True,
#    'seems': True,
#    'like': True,
#    'stealing': True,
#    'feature': True,
#    'without': True,
#    'reputation': True,
#    'pull': True},
#   'Negative'),
#  ({'dystopian': True, 'face': True, 'recognition': True, 'b': True},
#   'Positive'),
#  ({'ok': True}, 'Positive'),
#  ({'enjoying': True, 'app': True}, 'Positive'),
#  ({'save': True,
#    'money': True,
#    'buy': True,
#    'gym': True,
#    'membership': True,
#    'app': True,
#    'hookup': True,
#    'scammer': True,
#    'degenerate': True},
#   'Positive'),
#  ({'one': True,
#    'worst': True,
#    'dating': True,
#    'apps': True,
#    'profile': True,
#    'fake': True,
#    'bummer': True,
#    'use': True,
#    'good': True,
#    'back': True,
#    'day': True},
#   'Negative'),
#  ({'convert': True, 'zar': True, 'rand': True}, 'Positive'),
#  ({'every': True,
#    'account': True,
#    'match': True,
#    'start': True,
#    'normal': True,
#    'ask': True,
#    'subscribe': True,
#    'bot': True,
#    'also': True,
#    'clearly': True,
#    'snapchat': True,
#    'handle': True,
#    'added': True,
#    'yet': True,
#    'way': True,
#    'get': True,
#    'taken': True,
#    'instantly': True,
#    'pay': True,
#    'money': True,
#    'disappointed': True,
#    'better': True},
#   'Negative'),
#  ({'tinder': True,
#    'various': True,
#    'time': True,
#    'always': True,
#    'disappointed': True,
#    'push': True,
#    'upgrade': True,
#    'consistent': True,
#    'tiresome': True,
#    'notification': True,
#    'reminding': True,
#    'like': True,
#    'profile': True,
#    'annoying': True,
#    'slow': True,
#    'trickle': True,
#    'somehow': True,
#    'seen': True,
#    'though': True,
#    'ran': True,
#    'new': True,
#    'area': True,
#    'telling': True,
#    'application': True,
#    'hide': True,
#    'garbage': True,
#    'dating': True,
#    'app': True,
#    'ruining': True,
#    'world': True,
#    'superficial': True,
#    'obvious': True,
#    'money': True,
#    'grab': True,
#    'company': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'man': True,
#    'use': True,
#    'app': True,
#    'paid': True,
#    'used': True,
#    'year': True,
#    'literally': True,
#    'met': True,
#    'one': True,
#    'person': True,
#    'imo': True,
#    'predatory': True,
#    'towards': True,
#    'men': True,
#    'get': True,
#    'spend': True,
#    'much': True,
#    'money': True,
#    'possible': True,
#    'never': True,
#    'recommend': True,
#    'anyone': True,
#    'ever': True,
#    'fact': True,
#    'steer': True,
#    'people': True,
#    'away': True},
#   'Negative'),
#  ({'cant': True, 'delete': True}, 'Positive'),
#  ({'lot': True,
#    'fake': True,
#    'account': True,
#    'scammer': True,
#    'dishonest': True,
#    'people': True,
#    'cesspool': True,
#    'degenerate': True,
#    'pretending': True,
#    'look': True,
#    'love': True,
#    'wrong': True,
#    'place': True,
#    'addicted': True,
#    'validation': True,
#    'seek': True,
#    'intimacy': True},
#   'Negative'),
#  ({'amazing': True, 'app': True}, 'Positive'),
#  ({'poor': True, 'app': True}, 'Negative'),
#  ({'profile': True,
#    'female': True,
#    'fake': True,
#    'verified': True,
#    'many': True,
#    'photo': True,
#    'low': True,
#    'key': True,
#    'influencer': True,
#    'instagram': True,
#    'app': True,
#    'worth': True,
#    'anyone': True,
#    'time': True},
#   'Negative'),
#  ({'keep': True,
#    'matching': True,
#    'fat': True,
#    'uggos': True,
#    'profile': True,
#    'let': True,
#    'update': True,
#    'love': True,
#    'beautiful': True,
#    'woman': True,
#    'zaythen': True,
#    'ravi': True,
#    'moloch': True,
#    'wrong': True,
#    'bebe': True,
#    'rexha': True,
#    'could': True,
#    'app': True,
#    'would': True,
#    'reject': True,
#    'maybe': True,
#    'ugly': True,
#    'unattractive': True,
#    'god': True},
#   'Negative'),
#  ({'great': True, 'app': True}, 'Positive'),
#  ({'may': True, 'scammer': True, 'diyan': True, 'guy': True}, 'Positive'),
#  ({'paid': True,
#    'month': True,
#    'tinder': True,
#    'gold': True,
#    'log': True,
#    'week': True,
#    'sign': True,
#    'back': True,
#    'take': True,
#    'half': True,
#    'day': True,
#    'match': True,
#    'pop': True,
#    'funny': True,
#    'work': True},
#   'Positive'),
#  ({'fun': True,
#    'sometimes': True,
#    'take': True,
#    'long': True,
#    'actually': True,
#    'meet': True,
#    'want': True,
#    'time': True,
#    'friday': True,
#    'saturday': True,
#    'better': True,
#    'start': True,
#    'looking': True,
#    'beginning': True,
#    'week': True,
#    'haha': True},
#   'Positive'),
#  ({'dating': True,
#    'app': True,
#    'art': True,
#    'gallery': True,
#    'many': True,
#    'fake': True,
#    'bot': True,
#    'account': True,
#    'displaying': True,
#    'various': True,
#    'photo': True,
#    'painted': True,
#    'surface': True,
#    'flower': True,
#    'nature': True,
#    'etc': True,
#    'anime': True,
#    'people': True,
#    'pretty': True,
#    'sure': True,
#    'mostly': True,
#    'ai': True,
#    'image': True,
#    'like': True,
#    'looking': True,
#    'tacky': True,
#    'wallpaper': True,
#    'spread': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({'good': True, 'app': True, 'payment': True}, 'Positive'),
#  ({'total': True,
#    'po': True,
#    'barely': True,
#    'match': True,
#    'manipulative': True,
#    'tactic': True,
#    'unmatches': True,
#    'randomly': True,
#    'appear': True,
#    'course': True,
#    'vibe': True,
#    'f': True,
#    'uped': True,
#    'interruption': True,
#    'really': True,
#    'good': True,
#    'yr': True,
#    'ago': True,
#    'nowadays': True,
#    'money': True},
#   'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'full': True,
#    'perverted': True,
#    'men': True,
#    'quite': True,
#    'frankly': True,
#    'need': True,
#    'locking': True,
#    'absolute': True,
#    'extortionate': True,
#    'price': True,
#    'bombarded': True,
#    'creepy': True,
#    'weirdo': True,
#    'still': True,
#    'actual': True,
#    'update': True,
#    'month': True,
#    'later': True,
#    'think': True,
#    'met': True,
#    'least': True,
#    'three': True,
#    'jeffree': True,
#    'dahmer': True,
#    'wannabe': True,
#    'app': True,
#    'spend': True,
#    'money': True},
#   'Negative'),
#  ({'came': True,
#    'drop': True,
#    'review': True,
#    'noticed': True,
#    'already': True,
#    'one': True,
#    'since': True,
#    'well': True,
#    'edited': True,
#    'star': True,
#    'reason': True,
#    'give': True,
#    'user': True,
#    'locking': True,
#    'blocking': True,
#    'account': True,
#    'wrong': True,
#    'selfish': True,
#    'malicious': True,
#    'person': True,
#    'report': True,
#    'exactly': True},
#   'Negative'),
#  ({'app': True,
#    'horrible': True,
#    'understand': True,
#    'pay': True,
#    'see': True,
#    'like': True,
#    'get': True,
#    'short': True,
#    'limited': True,
#    'well': True,
#    'together': True,
#    'better': True,
#    'using': True,
#    'hookup': True},
#   'Negative'),
#  ({'fact': True, 'pay': True, 'service': True, 'joke': True}, 'Negative'),
#  ({'bot': True, 'heavy': True, 'identity': True, 'theft': True}, 'Negative'),
#  ({'spent': True,
#    'u': True,
#    'swiped': True,
#    'every': True,
#    'girl': True,
#    'matching': True,
#    'year': True,
#    'old': True,
#    'woman': True,
#    'germany': True,
#    'guess': True,
#    'unalive': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'absolutely': True,
#    'terrible': True,
#    'wish': True,
#    'could': True,
#    'get': True,
#    'time': True,
#    'back': True,
#    'documentary': True,
#    'year': True,
#    'damaging': True,
#    'harmful': True,
#    'app': True,
#    'humanity': True,
#    'please': True,
#    'run': True,
#    'far': True,
#    'away': True},
#   'Negative'),
#  ({'keep': True, 'buffering': True}, 'Positive'),
#  ({'tender': True,
#    'block': True,
#    'account': True,
#    'without': True,
#    'telling': True,
#    'appeal': True,
#    'unblocked': True,
#    'tried': True,
#    'multiple': True,
#    'time': True,
#    'try': True,
#    'get': True,
#    'customer': True,
#    'nothing': True,
#    'would': True,
#    'like': True,
#    'back': True,
#    'every': True,
#    'appealed': True,
#    'keep': True,
#    'sending': True,
#    'email': True,
#    'go': True,
#    'app': True,
#    'clearly': True,
#    'knowing': True,
#    'banned': True,
#    'told': True,
#    'preached': True,
#    'term': True,
#    'service': True,
#    'tell': True,
#    'one': True,
#    'breached': True,
#    'download': True},
#   'Negative'),
#  ({'horrible': True,
#    'experience': True,
#    'got': True,
#    'banned': True,
#    'multiple': True,
#    'time': True,
#    'ever': True,
#    'even': True,
#    'messaged': True,
#    'someone': True,
#    'every': True,
#    'excuse': True,
#    'sun': True,
#    'appealed': True,
#    'declined': True},
#   'Negative'),
#  ({'best': True, 'social': True, 'medium': True}, 'Positive'),
#  ({'complete': True, 'b': True}, 'Positive'),
#  ({'unless': True,
#    'pay': True,
#    'gold': True,
#    'rip': True,
#    'barely': True,
#    'get': True,
#    'match': True,
#    'preference': True,
#    'guy': True},
#   'Positive'),
#  ({'tinder': True,
#    'liable': True,
#    'fraud': True,
#    'ad': True,
#    'viewing': True,
#    'payment': True,
#    'many': True,
#    'option': True,
#    'fake': True,
#    'controlled': True,
#    'paying': True,
#    'nothing': True,
#    'match': True,
#    'get': True,
#    'decent': True,
#    'amount': True,
#    'like': True,
#    'come': True,
#    'across': True,
#    'account': True,
#    'name': True,
#    'automatically': True,
#    'chat': True,
#    'confirm': True,
#    'real': True,
#    'person': True,
#    'time': True,
#    'acc': True,
#    'photo': True,
#    'send': True,
#    'msg': True,
#    'disappears': True,
#    'month': True,
#    'yet': True,
#    'never': True},
#   'Negative'),
#  ({'pro': True,
#    'cutting': True,
#    'edge': True,
#    'feature': True,
#    'intuitive': True,
#    'design': True,
#    'seamless': True,
#    'user': True,
#    'experience': True,
#    'con': True,
#    'annoying': True,
#    'pop': True,
#    'encouraging': True,
#    'purchase': True,
#    'super': True,
#    'like': True,
#    'disrupts': True,
#    'sending': True,
#    'process': True,
#    'purchased': True,
#    'tinder': True,
#    'staff': True,
#    'claim': True,
#    'bug': True,
#    'every': True,
#    'product': True,
#    'extremely': True,
#    'expensive': True,
#    'especially': True,
#    'boost': True,
#    'doubt': True,
#    'men': True,
#    'willing': True,
#    'pay': True,
#    'equivalent': True,
#    'cost': True,
#    'sex': True,
#    'worker': True,
#    'bunch': True},
#   'Negative'),
#  ({'worst': True,
#    'app': True,
#    'ever': True,
#    'service': True,
#    'crash': True,
#    'lot': True,
#    'seeing': True,
#    'profile': True,
#    'even': True,
#    'able': True,
#    'delete': True,
#    'help': True,
#    'team': True},
#   'Negative'),
#  ({'human': True, 'verification': True, 'load': True, 'log': True},
#   'Negative'),
#  ({'pay': True, 'win': True}, 'Positive'),
#  ({'worst': True,
#    'apo': True,
#    'money': True,
#    'minded': True,
#    'everytime': True,
#    'asking': True,
#    'pay': True,
#    'manipulating': True,
#    'one': True,
#    'match': True,
#    'investment': True,
#    'fraudster': True,
#    'seen': True,
#    'anyone': True,
#    'yet': True,
#    'good': True,
#    'experience': True,
#    'tinder': True},
#   'Negative'),
#  ({'better': True, 'dating': True, 'apps': True, 'far': True}, 'Positive'),
#  ({'hot': True, 'simulator': True}, 'Positive'),
#  ({'found': True, 'offer': True, 'unacceptable': True}, 'Negative'),
#  ({'least': True,
#    'account': True,
#    'fake': True,
#    'charging': True,
#    'unlimited': True,
#    'like': True,
#    'see': True,
#    'scam': True,
#    'link': True,
#    'allow': True,
#    'app': True,
#    'fraud': True},
#   'Negative'),
#  ({'stupid': True, 'app': True, 'cannot': True, 'u': True}, 'Negative'),
#  ({'decent': True, 'way': True, 'many': True, 'bot': True}, 'Positive'),
#  ({}, 'Positive'),
#  ({'lovely': True}, 'Positive'),
#  ({'many': True, 'bot': True}, 'Positive'),
#  ({'excellent': True}, 'Positive'),
#  ({'video': True,
#    'verification': True,
#    'everyone': True,
#    'else': True,
#    'treated': True,
#    'way': True,
#    'access': True,
#    'account': True,
#    'yet': True,
#    'blocked': True,
#    'using': True,
#    'dating': True,
#    'app': True},
#   'Negative'),
#  ({'ime': True}, 'Positive'),
#  ({'make': True, 'sense': True, 'hope': True, 'find': True, 'soulmate': True},
#   'Positive'),
#  ({'joke': True}, 'Negative'),
#  ({'bad': True, 'app': True}, 'Negative'),
#  ({'nice': True, 'best': True, 'dating': True, 'app': True}, 'Positive'),
#  ({'ok': True}, 'Positive'),
#  ({'good': True, 'app': True}, 'Positive'),
#  ({'month': True,
#    'one': True,
#    'respond': True,
#    'appeal': True,
#    'reason': True,
#    'ban': True,
#    'great': True,
#    'support': True,
#    'loyal': True,
#    'user': True,
#    'year': True},
#   'Positive'),
#  ({'frequent': True,
#    'pop': True,
#    'ups': True,
#    'prompting': True,
#    'send': True,
#    'super': True,
#    'like': True,
#    'cover': True,
#    'half': True,
#    'information': True,
#    'profile': True,
#    'looking': True,
#    'extremely': True,
#    'annoying': True,
#    'every': True,
#    'swipe': True,
#    'another': True,
#    'prompt': True,
#    'share': True,
#    'common': True,
#    'interest': True,
#    'etc': True,
#    'badly': True,
#    'designed': True,
#    'migrating': True,
#    'boo': True,
#    'better': True,
#    'interface': True,
#    'reasonable': True,
#    'price': True},
#   'Negative'),
#  ({'nice': True}, 'Positive'),
#  ({'cancel': True, 'subscription': True}, 'Positive'),
#  ({'premium': True,
#    'na': True,
#    'use': True,
#    'kore': True,
#    'free': True,
#    'jodi': True,
#    'kisu': True,
#    'kora': True,
#    'jaito': True,
#    'valo': True,
#    'hoito': True},
#   'Positive'),
#  ({'tinder': True,
#    'randomly': True,
#    'logged': True,
#    'big': True,
#    'deal': True,
#    'however': True,
#    'erased': True,
#    'match': True,
#    'go': True,
#    'without': True,
#    'saying': True,
#    'extremely': True,
#    'frustrating': True,
#    'even': True,
#    'opted': True,
#    'buy': True,
#    'gold': True,
#    'considering': True,
#    'vanish': True,
#    'moment': True,
#    'notice': True},
#   'Negative'),
#  ({'day': True,
#    'selfie': True,
#    'verification': True,
#    'still': True,
#    'review': True,
#    'submitted': True,
#    'multiple': True,
#    'email': True,
#    'complaint': True,
#    'nothing': True,
#    'resolved': True,
#    'received': True,
#    'response': True,
#    'service': True,
#    'really': True,
#    'poor': True,
#    'tinder': True,
#    'need': True,
#    'speed': True,
#    'process': True,
#    'improve': True,
#    'customer': True,
#    'support': True,
#    'disappointing': True,
#    'experience': True,
#    'far': True},
#   'Negative'),
#  ({'okay': True}, 'Positive'),
#  ({'alot': True, 'men': True, 'fish': True, 'love': True, 'lol': True},
#   'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'absolutely': True,
#    'terrible': True,
#    'app': True,
#    'year': True,
#    'ago': True,
#    'alright': True,
#    'zero': True,
#    'like': True,
#    'bot': True,
#    'account': True},
#   'Negative'),
#  ({'good': True, 'app': True}, 'Positive'),
#  ({'absolutely': True,
#    'useless': True,
#    'app': True,
#    'waste': True,
#    'money': True,
#    'time': True,
#    'support': True,
#    'grab': True,
#    'trying': True,
#    'unsubscribe': True,
#    'payment': True,
#    'absolute': True,
#    'nightmare': True},
#   'Negative'),
#  ({'nice': True, 'apps': True}, 'Positive'),
#  ({'expensive': True}, 'Positive'),
#  ({'love': True, 'bad': True, 'boy': True}, 'Negative'),
#  ({'rediculous': True,
#    'see': True,
#    'like': True,
#    'able': True,
#    'msg': True,
#    'price': True,
#    'way': True,
#    'high': True},
#   'Negative'),
#  ({'cool': True}, 'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'created': True,
#    'new': True,
#    'account': True,
#    'asks': True,
#    'verify': True,
#    'human': True,
#    'sitting': True,
#    'minute': True,
#    'figuring': True,
#    'math': True,
#    'puzzle': True,
#    'even': True,
#    'like': True,
#    'try': True,
#    'picture': True,
#    'let': True,
#    'alone': True,
#    'solve': True,
#    'trying': True,
#    'get': True,
#    'back': True,
#    'still': True,
#    'keep': True,
#    'scammer': True,
#    'fake': True,
#    'yet': True,
#    'making': True,
#    'people': True,
#    'mean': True,
#    'thought': True,
#    'process': True},
#   'Negative'),
#  ({'bad': True}, 'Negative'),
#  ({'multiple': True,
#    'time': True,
#    'taken': True,
#    'money': True,
#    'fot': True,
#    'boost': True,
#    'provided': True,
#    'way': True,
#    'redeem': True},
#   'Negative'),
#  ({'scam': True,
#    'golden': True,
#    'month': True,
#    'literally': True,
#    'hundred': True,
#    'thousand': True,
#    'like': True,
#    'given': True,
#    'day': True,
#    'match': True,
#    'whole': True,
#    'time': True,
#    'really': True,
#    'tinder': True,
#    'bigger': True,
#    'money': True,
#    'farm': True,
#    'ex': True,
#    'wife': True},
#   'Negative'),
#  ({'wate': True,
#    'app': True,
#    'worst': True,
#    'give': True,
#    'star': True,
#    'rate': True},
#   'Negative'),
#  ({'thank': True, 'much': True}, 'Positive'),
#  ({'dead': True, 'app': True}, 'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'unable': True,
#    'verify': True,
#    'phone': True,
#    'number': True,
#    'zambia': True,
#    'delete': True,
#    'app': True,
#    'log': True,
#    'thw': True,
#    'verification': True,
#    'code': True,
#    'coming': True},
#   'Negative'),
#  ({'absolutely': True,
#    'ruined': True,
#    'app': True,
#    'requires': True,
#    'minimum': True,
#    'photo': True,
#    'see': True,
#    'people': True,
#    'max': True,
#    'positive': True,
#    'swipe': True,
#    'bumbles': True,
#    'hour': True,
#    'timer': True,
#    'chat': True,
#    'match': True,
#    'next': True,
#    'paying': True,
#    'single': True,
#    'right': True,
#    'better': True,
#    'year': True,
#    'ago': True,
#    'even': True,
#    'still': True,
#    'horrible': True},
#   'Negative'),
#  ({'everything': True, 'neeed': True, 'money': True}, 'Negative'),
#  ({'ichooooo': True}, 'Positive'),
#  ({'quality': True, 'course': True}, 'Positive'),
#  ({'full': True,
#    'bot': True,
#    'fan': True,
#    'model': True,
#    'start': True,
#    'conversation': True,
#    'someone': True,
#    'two': True,
#    'message': True,
#    'basic': True,
#    'hey': True,
#    'going': True,
#    'respond': True,
#    'reply': True,
#    'befor': True,
#    'even': True,
#    'sent': True,
#    'person': True,
#    'messaged': True,
#    'first': True,
#    'longer': True,
#    'inbox': True,
#    'tinder': True,
#    'money': True,
#    'grab': True,
#    'app': True,
#    'liked': True,
#    'everyone': True,
#    'within': True,
#    'mile': True,
#    'got': True,
#    'match': True,
#    'week': True,
#    'span': True},
#   'Positive'),
#  ({'found': True,
#    'life': True,
#    'partner': True,
#    'really': True,
#    'trust': True,
#    'without': True,
#    'subscription': True,
#    'got': True,
#    'totally': True,
#    'depends': True,
#    'luck': True,
#    'happy': True,
#    'app': True},
#   'Positive'),
#  ({'hell': True,
#    'everytime': True,
#    'match': True,
#    'disappearing': True,
#    'chat': True,
#    'going': True,
#    'please': True,
#    'fix': True,
#    'issue': True,
#    'recover': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'nice': True}, 'Positive'),
#  ({'message': True,
#    'sent': True,
#    'received': True,
#    'free': True,
#    'drop': True,
#    'price': True,
#    'allow': True,
#    'people': True,
#    'actually': True,
#    'pay': True,
#    'per': True,
#    'month': True,
#    'instead': True,
#    'lump': True,
#    'payment': True,
#    'cool': True,
#    'stop': True,
#    'taking': True,
#    'advantage': True,
#    'wish': True,
#    'connect': True,
#    'meet': True,
#    'like': True,
#    'minded': True,
#    'capitalism': True,
#    'ruining': True,
#    'everything': True,
#    'thanks': True},
#   'Negative'),
#  ({'met': True, 'someone': True, 'cool': True, 'af': True}, 'Positive'),
#  ({'stupid': True, 'app': True}, 'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'turned': True,
#    'almost': True,
#    'exclusively': True,
#    'onlyfans': True,
#    'snapchat': True,
#    'instagram': True,
#    'promotion': True,
#    'absolutely': True,
#    'intention': True,
#    'meeting': True,
#    'app': True,
#    'also': True,
#    'complete': True,
#    'scam': True,
#    'us': True,
#    'dark': True,
#    'trick': True,
#    'manipulate': True,
#    'consumer': True,
#    'would': True,
#    'rate': True,
#    'negative': True,
#    'point': True,
#    'possible': True,
#    'use': True,
#    'apps': True,
#    'suggestion': True,
#    'matter': True},
#   'Negative'),
#  ({'bot': True,
#    'scammer': True,
#    'download': True,
#    'let': True,
#    'app': True,
#    'die': True},
#   'Positive'),
#  ({'shocking': True, 'site': True}, 'Negative'),
#  ({'nice': True}, 'Positive'),
#  ({'nicee': True}, 'Positive'),
#  ({'unable': True,
#    'delete': True,
#    'account': True,
#    'app': True,
#    'neither': True,
#    'able': True,
#    'use': True,
#    'frustrating': True,
#    'trying': True,
#    'multiple': True,
#    'time': True,
#    'support': True,
#    'team': True,
#    'yet': True,
#    'even': True,
#    'raising': True,
#    'issue': True,
#    'request': True,
#    'urgent': True,
#    'assistance': True,
#    'fixing': True},
#   'Negative'),
#  ({'photo': True,
#    'selector': True,
#    'garbage': True,
#    'system': True,
#    'overall': True,
#    'unpleasant': True,
#    'use': True},
#   'Negative'),
#  ({'nice': True, 'app': True}, 'Positive'),
#  ({'bad': True}, 'Negative'),
#  ({'scam': True,
#    'ether': True,
#    'tinder': True,
#    'flooding': True,
#    'inbox': True,
#    'bot': True,
#    'control': True,
#    'people': True,
#    'making': True,
#    'fake': True,
#    'account': True,
#    'pay': True,
#    'real': True,
#    'interaction': True,
#    'wish': True,
#    'could': True,
#    'get': True,
#    'money': True,
#    'back': True,
#    'fix': True,
#    'verify': True,
#    'facebook': True,
#    'right': True},
#   'Negative'),
#  ({'seem': True,
#    'respect': True,
#    'user': True,
#    'time': True,
#    'trying': True,
#    'milk': True,
#    'money': True,
#    'frequently': True,
#    'give': True,
#    'notification': True,
#    'like': True,
#    'clicked': True,
#    'also': True,
#    'match': True,
#    'people': True,
#    'without': True,
#    'told': True,
#    'shown': True,
#    'way': True,
#    'outside': True,
#    'range': True,
#    'always': True,
#    'throttling': True,
#    'get': True,
#    'awhile': True,
#    'start': True,
#    'etc': True,
#    'heavy': True,
#    'engineering': True,
#    'geared': True,
#    'try': True,
#    'profit': True,
#    'instead': True,
#    'free': True,
#    'use': True},
#   'Negative'),
#  ({'basic': True, 'swiping': True, 'dating': True, 'app': True}, 'Positive'),
#  ({'know': True,
#    'payment': True,
#    'option': True,
#    'get': True,
#    'feature': True,
#    'permanently': True,
#    'like': True,
#    'pay': True,
#    'weekly': True,
#    'monthly': True,
#    'even': True,
#    'yearly': True,
#    'tinder': True,
#    'rip': True,
#    'people': True,
#    'concept': True,
#    'offering': True,
#    'straight': True,
#    'offs': True,
#    'application': True,
#    'hardly': True,
#    'give': True,
#    'match': True,
#    'free': True,
#    'user': True,
#    'annoying': True,
#    'also': True,
#    'use': True,
#    'number': True,
#    'want': True,
#    'verify': True,
#    'email': True,
#    'stupid': True},
#   'Negative'),
#  ({'un': True, 'able': True, 'delete': True, 'account': True}, 'Positive'),
#  ({'absolute': True,
#    'garbage': True,
#    'pay': True,
#    'subscription': True,
#    'damn': True,
#    'expensive': True,
#    'message': True,
#    'anyone': True,
#    'burnt': True},
#   'Negative'),
#  ({'dating': True, 'app': True, 'next': True}, 'Positive'),
#  ({'day': True,
#    'subscribing': True,
#    'gold': True,
#    'package': True,
#    'unable': True,
#    'login': True,
#    'account': True,
#    'deleted': True,
#    'app': True,
#    'reinstalled': True,
#    'issue': True,
#    'still': True,
#    'remains': True,
#    'updated': True,
#    'work': True,
#    'contacted': True,
#    'customer': True,
#    'service': True,
#    'useful': True,
#    'really': True,
#    'want': True,
#    'match': True,
#    'nice': True,
#    'sweet': True,
#    'please': True},
#   'Negative'),
#  ({'good': True, 'app': True, 'find': True, 'genuiun': True, 'person': True},
#   'Positive'),
#  ({'paid': True,
#    'platinum': True,
#    'several': True,
#    'time': True,
#    'latest': True,
#    'month': True,
#    'little': True,
#    'success': True,
#    'expired': True,
#    'tonight': True,
#    'suddenly': True,
#    'like': True,
#    'pay': True,
#    'service': True,
#    'get': True,
#    'con': True,
#    'know': True,
#    'people': True,
#    'think': True,
#    'luck': True,
#    'draw': True,
#    'chosen': True,
#    'account': True,
#    'severe': True,
#    'issue': True,
#    'fake': True,
#    'bot': True,
#    'total': True,
#    'waster': True,
#    'many': True,
#    'lady': True,
#    'advertising': True,
#    'instagram': True,
#    'onlyfans': True,
#    'social': True,
#    'medium': True,
#    'dating': True,
#    'app': True,
#    'egoboost': True},
#   'Negative'),
#  ({'day': True,
#    'swiping': True,
#    'within': True,
#    'mile': True,
#    'gotta': True,
#    'match': True,
#    'none': True,
#    'lb': True},
#   'Positive'),
#  ({'mala': True,
#    'experiencia': True,
#    'con': True,
#    'la': True,
#    'aplicaci': True,
#    'n': True,
#    'solo': True,
#    'un': True,
#    'medio': True,
#    'para': True,
#    'estafar': True,
#    'los': True,
#    'usuarios': True,
#    'te': True,
#    'presentar': True,
#    'perfiles': True,
#    'sin': True,
#    'ninguna': True,
#    'posibilidad': True,
#    'de': True,
#    'match': True},
#   'Negative'),
#  ({'free': True, 'love': True, 'whoever': True}, 'Positive'),
#  ({'still': True, 'fence': True, 'one': True}, 'Positive'),
#  ({'getting': True, 'match': True, 'nice': True}, 'Positive'),
#  ({'legit': True}, 'Positive'),
#  ({'good': True, 'app': True, 'need': True, 'careful': True}, 'Positive'),
#  ({'exploitative': True,
#    'every': True,
#    'step': True,
#    'need': True,
#    'pay': True,
#    'recomend': True},
#   'Negative'),
#  ({'loveeeee': True}, 'Positive'),
#  ({'people': True,
#    'within': True,
#    'hour': True,
#    'drive': True,
#    'live': True,
#    'large': True,
#    'lightly': True,
#    'populated': True,
#    'county': True},
#   'Positive'),
#  ({'gud': True}, 'Positive'),
#  ({'pay': True, 'everything': True}, 'Positive'),
#  ({'many': True, 'bot': True, 'need': True, 'filter': True, 'spam': True},
#   'Positive'),
#  ({'poor': True,
#    'compared': True,
#    'sophisticated': True,
#    'apps': True,
#    'even': True,
#    'paid': True,
#    'screen': True,
#    'still': True,
#    'taken': True,
#    'tinder': True,
#    'upgrade': True,
#    'option': True,
#    'could': True,
#    'never': True,
#    'recommend': True,
#    'definitely': True,
#    'better': True,
#    'dating': True,
#    'site': True},
#   'Negative'),
#  ({'subscribed': True,
#    'premium': True,
#    'came': True,
#    'renewal': True,
#    'blocked': True,
#    'account': True,
#    'banned': True,
#    'anything': True,
#    'inappropriate': True,
#    'illegal': True},
#   'Negative'),
#  ({'keep': True,
#    'showing': True,
#    'profile': True,
#    'buggy': True,
#    'waste': True,
#    'time': True,
#    'app': True},
#   'Negative'),
#  ({'perfect': True}, 'Positive'),
#  ({'wow': True,
#    'background': True,
#    'great': True,
#    'nice': True,
#    'love': True,
#    'app': True},
#   'Positive'),
#  ({'nice': True}, 'Positive'),
#  ({'message': True,
#    'disappear': True,
#    'happened': True,
#    'quite': True,
#    'time': True,
#    'two': True,
#    'different': True,
#    'phone': True,
#    'suck': True,
#    'important': True,
#    'number': True,
#    'way': True,
#    'recover': True,
#    'defeat': True,
#    'purpose': True,
#    'app': True,
#    'completely': True,
#    'update': True,
#    'almost': True,
#    'daily': True,
#    'receiving': True,
#    'notification': True,
#    'got': True,
#    'match': True,
#    'sent': True,
#    'open': True,
#    'literally': True,
#    'hear': True,
#    'sound': True,
#    'nothing': True,
#    'even': True,
#    'ridiculous': True},
#   'Negative'),
#  ({'app': True, 'full': True, 'bot': True}, 'Positive'),
#  ({'cute': True}, 'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'many': True,
#    'bot': True,
#    'fake': True,
#    'profile': True,
#    'price': True,
#    'limitation': True,
#    'force': True,
#    'stupid': True,
#    'hard': True,
#    'meet': True,
#    'potential': True,
#    'match': True,
#    'due': True,
#    'gouging': True,
#    'make': True,
#    'tinder': True,
#    'feel': True,
#    'like': True,
#    'pyramid': True,
#    'scheme': True,
#    'algorithm': True,
#    'made': True,
#    'pay': True,
#    'feature': True,
#    'improve': True,
#    'anything': True,
#    'worthwhile': True,
#    'ai': True,
#    'good': True,
#    'luck': True,
#    'finding': True,
#    'anyone': True,
#    'involved': True},
#   'Negative'),
#  ({'banned': True,
#    'even': True,
#    'though': True,
#    'dont': True,
#    'account': True,
#    'ever': True,
#    'app': True,
#    'life': True,
#    'entered': True,
#    'phone': True,
#    'number': True,
#    'bam': True,
#    'swear': True,
#    'ive': True,
#    'never': True,
#    'used': True,
#    'customer': True,
#    'help': True,
#    'horrible': True,
#    'know': True,
#    'recycled': True,
#    'edit': True,
#    'still': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'nice': True}, 'Positive'),
#  ({'warned': True,
#    'dangerous': True,
#    'app': True,
#    'install': True,
#    'much': True,
#    'fishing': True,
#    'fake': True,
#    'account': True,
#    'tried': True,
#    'delete': True,
#    'profile': True,
#    'failed': True,
#    'way': True,
#    'communicate': True,
# ...
#  ({'stay': True,
#    'away': True,
#    'use': True,
#    'ok': True,
#    'dating': True,
#    'app': True,
#    'full': True,
#    'scamers': True,
#    'also': True,
#    'tinder': True,
#    'customer': True,
#    'service': True,
#    'try': True,
#    'get': True,
#    'money': True,
#    'instead': True,
#    'helping': True,
#    'cancelled': True,
#    'subscrition': True,
#    'previous': True,
#    'alert': True,
#    'without': True,
#    'contact': True,
#    'anything': True,
#    'email': True,
#    'option': True,
#    'inside': True,
#    'chat': True,
#    'platinium': True,
#    'subscription': True,
#    'year': True,
#    'price': True,
#    'fraud': True,
#    'say': True,
#    'cannot': True,
#    'help': True,
#    'nowdays': True,
#    'mainly': True,
#    'scammer': True,
#    'onlyfans': True,
#    'girl': True,
#    'advertize': True,
#    'themself': True},
#   'Negative'),
#  ({'baddd': True}, 'Negative'),
#  ({'happy': True}, 'Positive'),
#  ({'hihi': True}, 'Positive'),
#  ({'hope': True, 'find': True, 'soulmate': True}, 'Positive'),
#  ({'cat': True, 'soft': True}, 'Negative'),
#  ({'fake': True, 'account': True}, 'Negative'),
#  ({'fake': True, 'people': True}, 'Negative'),
#  ({'location': True}, 'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'good': True, 'dating': True, 'app': True}, 'Positive'),
#  ({'worst': True,
#    'ever': True,
#    'recommend': True,
#    'anyone': True,
#    'wonder': True,
#    'people': True,
#    'come': True,
#    'good': True,
#    'review': True,
#    'experience': True,
#    'hell': True},
#   'Negative'),
#  ({'matining': True, 'pogie': True}, 'Positive'),
#  ({'great': True, 'one': True}, 'Positive'),
#  ({'tinder': True, 'gold': True, 'scam': True}, 'Negative'),
#  ({'waste': True,
#    'time': True,
#    'download': True,
#    'went': True,
#    'process': True,
#    'verifying': True,
#    'end': True,
#    'account': True,
#    'got': True,
#    'flagged': True,
#    'say': True,
#    'restriction': True,
#    'would': True,
#    'applied': True,
#    'blacklisted': True,
#    'leaving': True,
#    'useless': True,
#    'delete': True,
#    'info': True,
#    'picture': True,
#    'deletion': True,
#    'failed': True,
#    'profile': True,
#    'pointless': True,
#    'unable': True,
#    'used': True,
#    'bot': True,
#    'fake': True,
#    'app': True,
#    'promotes': True,
#    'bad': True,
#    'enough': True,
#    'save': True},
#   'Negative'),
#  ({'want': True,
#    'chat': True,
#    'someone': True,
#    'need': True,
#    'buy': True,
#    'first': True,
#    'gold': True,
#    'membership': True,
#    'otherwise': True,
#    'scroll': True},
#   'Negative'),
#  ({'exillent': True}, 'Negative'),
#  ({'poor': True}, 'Negative'),
#  ({'nice': True, 'app': True}, 'Positive'),
#  ({'perfect': True}, 'Positive'),
#  ({'aboslutely': True,
#    'pathetic': True,
#    'app': True,
#    'banned': True,
#    'reason': True,
#    'say': True,
#    'account': True,
#    'previously': True,
#    'first': True,
#    'time': True,
#    'even': True,
#    'using': True,
#    'paid': True,
#    'platinum': True,
#    'subscription': True,
#    'didnt': True,
#    'get': True,
#    'refund': True,
#    'managed': True,
#    'group': True,
#    'crook': True,
#    'thug': True},
#   'Negative'),
#  ({'great': True}, 'Positive'),
#  ({'take': True, 'long': True, 'match': True}, 'Positive'),
#  ({'locked': True,
#    'account': True,
#    'saying': True,
#    'suspicious': True,
#    'behaviour': True,
#    'kept': True,
#    'making': True,
#    'error': True,
#    'human': True,
#    'verification': True,
#    'test': True,
#    'btw': True,
#    'annoying': True,
#    'inconvenient': True,
#    'hope': True,
#    'guy': True,
#    'remove': True,
#    'least': True,
#    'make': True,
#    'simpler': True},
#   'Negative'),
#  ({'got': True,
#    'banned': True,
#    'away': True,
#    'tinder': True,
#    'almost': True,
#    'year': True,
#    'confused': True,
#    'never': True,
#    'really': True,
#    'date': True,
#    'bother': True,
#    'wanna': True,
#    'know': True,
#    'even': True,
#    'trying': True},
#   'Negative'),
#  ({'girl': True,
#    'swip': True,
#    'like': True,
#    'profile': True,
#    'liked': True,
#    'match': True,
#    'wanna': True,
#    'talk': True,
#    'unmatch': True,
#    'abit': True,
#    'silly': True,
#    'gonna': True,
#    'interested': True,
#    'embarrassing': True,
#    'app': True,
#    'tbh': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'app': True,
#    'rest': True,
#    'hate': True,
#    'deduct': True,
#    'people': True,
#    'swipe': True,
#    'left': True,
#    'number': True,
#    'like': True,
#    'show': True,
#    'bottom': True},
#   'Negative'),
#  ({'many': True, 'bot': True, 'fake': True, 'account': True}, 'Negative'),
#  ({}, 'Positive'),
#  ({'cool': True, 'meet': True, 'new': True, 'people': True}, 'Positive'),
#  ({'bogus': True,
#    'app': True,
#    'false': True,
#    'machining': True,
#    'shake': True},
#   'Negative'),
#  ({'interesting': True,
#    'platform': True,
#    'people': True,
#    'looking': True,
#    'new': True,
#    'friend': True},
#   'Positive'),
#  ({'buggy': True,
#    'app': True,
#    'sometimes': True,
#    'recent': True,
#    'match': True,
#    'disappear': True,
#    'reappear': True,
#    'currently': True,
#    'view': True,
#    'profile': True,
#    'glitch': True,
#    'straight': True,
#    'back': True,
#    'chat': True},
#   'Negative'),
#  ({'point': True,
#    'tinder': True,
#    'worst': True,
#    'fraud': True,
#    'like': True,
#    'subscribe': True,
#    'next': True,
#    'thing': True,
#    'blocking': True,
#    'account': True,
#    'verification': True,
#    'hour': True,
#    'uninstall': True,
#    'reopened': True,
#    'deleted': True,
#    'first': True,
#    'reopen': True,
#    'upgraded': True,
#    'guy': True,
#    'still': True,
#    'see': True,
#    'match': True,
#    'upgrading': True,
#    'day': True,
#    'keep': True,
#    'telling': True,
#    'verify': True,
#    'human': True,
#    'main': True,
#    'issue': True,
#    'taking': True,
#    'almost': True,
#    'forever': True,
#    'damn': True,
#    'ittt': True},
#   'Negative'),
#  ({'dog': True}, 'Positive'),
#  ({'lost': True,
#    'message': True,
#    'cannot': True,
#    'view': True,
#    'profile': True,
#    'people': True,
#    'im': True,
#    'matched': True,
#    'roo': True,
#    'many': True,
#    'fake': True,
#    'even': True,
#    'report': True,
#    'stay': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'good': True, 'lonely': True, 'person': True}, 'Positive'),
#  ({'good': True,
#    'app': True,
#    'fair': True,
#    'pay': True,
#    'seeing': True,
#    'match': True},
#   'Positive'),
#  ({'really': True, 'good': True}, 'Positive'),
#  ({'give': True,
#    'least': True,
#    'day': True,
#    'free': True,
#    'without': True,
#    'payment': True,
#    'using': True,
#    'app': True},
#   'Positive'),
#  ({'app': True,
#    'get': True,
#    'worse': True,
#    'every': True,
#    'time': True,
#    'install': True,
#    'fill': True,
#    'keep': True,
#    'locked': True,
#    'installed': True,
#    'two': True,
#    'day': True,
#    'ago': True,
#    'profile': True,
#    'verified': True,
#    'sudden': True,
#    'got': True,
#    'message': True,
#    'saying': True,
#    'photo': True,
#    'reviewed': True,
#    'next': True,
#    'white': True,
#    'screen': True,
#    'option': True,
#    'even': True,
#    'delete': True,
#    'course': True,
#    'also': True,
#    'losing': True,
#    'match': True},
#   'Negative'),
#  ({'great': True,
#    'experience': True,
#    'hope': True,
#    'find': True,
#    'partner': True},
#   'Positive'),
#  ({'lovely': True}, 'Positive'),
#  ({'work': True}, 'Negative'),
#  ({'work': True, 'got': True, 'friend': True, 'give': True, 'try': True},
#   'Positive'),
#  ({'nice': True, 'apps': True}, 'Positive'),
#  ({'far': True, 'good': True}, 'Positive'),
#  ({'nice': True, 'app': True}, 'Positive'),
#  ({'never': True,
#    'even': True,
#    'account': True,
#    'phone': True,
#    'number': True,
#    'banned': True,
#    'crazy': True,
#    'know': True,
#    'company': True,
#    'sale': True},
#   'Negative'),
#  ({'select': True,
#    'enm': True,
#    'banned': True,
#    'forever': True,
#    'happy': True},
#   'Negative'),
#  ({'many': True,
#    'damn': True,
#    'bot': True,
#    'quick': True,
#    'way': True,
#    'meet': True,
#    'people': True,
#    'bomarded': True,
#    'spam': True},
#   'Positive'),
#  ({'cool': True, 'app': True}, 'Positive'),
#  ({'forced': True,
#    'view': True,
#    'male': True,
#    'mental': True,
#    'illness': True,
#    'pretending': True,
#    'girl': True,
#    'interested': True,
#    'option': True,
#    'block': True,
#    'people': True,
#    'show': True,
#    'verified': True,
#    'user': True,
#    'see': True,
#    'account': True,
#    'get': True,
#    'harrased': True,
#    'fake': True,
#    'profile': True,
#    'ex': True,
#    'wife': True,
#    'better': True,
#    'come': True,
#    'back': True,
#    'also': True,
#    'add': True,
#    'pro': True,
#    'match': True,
#    'similar': True,
#    'lady': True},
#   'Negative'),
#  ({'got': True,
#    'ban': True,
#    'year': True,
#    'ago': True,
#    'posting': True,
#    'shooting': True,
#    'video': True,
#    'closed': True,
#    'range': True,
#    'way': True,
#    'appeal': True,
#    'lonely': True,
#    'forever': True},
#   'Negative'),
#  ({'good': True, 'app': True}, 'Positive'),
#  ({'got': True,
#    'banned': True,
#    'first': True,
#    'match': True,
#    'said': True,
#    'hey': True},
#   'Negative'),
#  ({'literally': True,
#    'worst': True,
#    'app': True,
#    'ever': True,
#    'used': True,
#    'let': True,
#    'fake': True,
#    'people': True,
#    'stay': True,
#    'real': True,
#    'account': True,
#    'ban': True},
#   'Negative'),
#  ({'excellent': True}, 'Positive'),
#  ({'recently': True,
#    'app': True,
#    'keep': True,
#    'resetting': True,
#    'lose': True,
#    'match': True,
#    'message': True},
#   'Positive'),
#  ({'poor': True,
#    'experience': True,
#    'review': True,
#    'option': True,
#    'click': True,
#    'example': True,
#    'mistake': True,
#    'finger': True,
#    'touched': True,
#    'upon': True,
#    'boost': True,
#    'button': True,
#    'start': True,
#    'stop': True,
#    'dislike': True},
#   'Negative'),
#  ({'filter': True,
#    'work': True,
#    'properly': True,
#    'even': True,
#    'titanium': True,
#    'customer': True,
#    'tinder': True,
#    'gots': True,
#    'name': True,
#    'need': True,
#    'working': True,
#    'instead': True,
#    'apps': True,
#    'far': True,
#    'better': True},
#   'Negative'),
#  ({'good': True}, 'Positive'),
#  ({'nice': True}, 'Positive'),
#  ({'waste': True, 'time': True}, 'Positive'),
#  ({'app': True,
#    'used': True,
#    'decent': True,
#    'meet': True,
#    'many': True,
#    'damn': True,
#    'false': True,
#    'account': True,
#    'annoying': True},
#   'Negative'),
#  ({'suck': True}, 'Positive'),
#  ({'many': True,
#    'fake': True,
#    'tinder': True,
#    'hide': True,
#    'profile': True,
#    'male': True,
#    'link': True,
#    'another': True,
#    'social': True,
#    'medium': True,
#    'allow': True,
#    'woman': True,
#    'advertise': True,
#    'different': True,
#    'sex': True,
#    'site': True,
#    'also': True,
#    'load': True,
#    'bot': True,
#    'designed': True,
#    'get': True,
#    'pay': True,
#    'premium': True,
#    'unlock': True,
#    'liked': True,
#    'dont': True,
#    'upgrade': True,
#    'scam': True,
#    'point': True,
#    'max': True,
#    'radius': True,
#    'change': True,
#    'time': True},
#   'Negative'),
#  ({'garbage': True,
#    'face': True,
#    'verification': True,
#    'even': True,
#    'use': True,
#    'proper': True,
#    'api': True,
#    'pixel': True,
#    'device': True,
#    'photo': True,
#    'always': True,
#    'come': True,
#    'blurry': True,
#    'fails': True,
#    'know': True,
#    'damn': True,
#    'well': True,
#    'camera': True},
#   'Negative'),
#  ({'debiln': True,
#    'aplikace': True,
#    'nepou': True,
#    'vejte': True,
#    'lep': True,
#    'je': True,
#    'badoo': True},
#   'Negative'),
#  ({'started': True,
#    'checking': True,
#    'site': True,
#    'look': True,
#    'good': True},
#   'Positive'),
#  ({'babbage': True}, 'Negative'),
#  ({'worst': True, 'experience': True}, 'Positive'),
#  ({'blocking': True,
#    'people': True,
#    'work': True,
#    'swiping': True,
#    'left': True,
#    'profile': True,
#    'appear': True,
#    'time': True,
#    'setting': True,
#    'app': True,
#    'notify': True,
#    'like': True,
#    'show': True,
#    'notification': True,
#    'recommended': True},
#   'Negative'),
#  ({'money': True, 'matter': True}, 'Positive'),
#  ({'hate': True, 'even': True, 'deserve': True, 'half': True, 'star': True},
#   'Negative'),
#  ({'badass': True}, 'Negative'),
#  ({'nice': True, 'app': True}, 'Positive'),
#  ({'claim': True,
#    'security': True,
#    'breach': True,
#    'force': True,
#    'selfie': True,
#    'verify': True,
#    'locked': True,
#    'platinum': True,
#    'paid': True,
#    'account': True,
#    'since': True,
#    'response': True,
#    'filing': True,
#    'inquiry': True,
#    'scam': True},
#   'Negative'),
#  ({'lot': True,
#    'date': True,
#    'current': True,
#    'gf': True,
#    'year': True,
#    'know': True,
#    'tinder': True,
#    'really': True,
#    'lol': True,
#    'anyways': True,
#    'find': True,
#    'gold': True,
#    'digger': True,
#    'dating': True,
#    'apps': True,
#    'cheater': True,
#    'careful': True,
#    'rubber': True,
#    'duck': True},
#   'Negative'),
#  ({'got': True, 'age': True, 'restricted': True, 'many': True, 'time': True},
#   'Positive'),
#  ({'awesome': True}, 'Positive'),
#  ({'edit': True,
#    'normaly': True,
#    'dont': True,
#    'change': True,
#    'rating': True,
#    'apps': True,
#    'im': True,
#    'sick': True,
#    'bull': True,
#    'pulling': True,
#    'lately': True,
#    'matched': True,
#    'wemon': True,
#    'sent': True,
#    'message': True,
#    'cant': True,
#    'see': True,
#    'hate': True,
#    'soo': True,
#    'much': True,
#    'care': True,
#    'scaming': True,
#    'let': True,
#    'say': True,
#    'likley': True,
#    'scam': True,
#    'also': True,
#    'tell': True,
#    'free': True,
#    'account': True,
#    'arent': True,
#    'penilized': True,
#    'original': True,
#    'would': True,
#    'great': True,
#    'paid': True,
#    'subscription': True,
#    'add': True,
#    'interactive': True,
#    'story': True,
#    'tho': True},
#   'Negative'),
#  ({'supar': True}, 'Positive'),
#  ({'tak': True,
#    'boleh': True,
#    'guna': True,
#    'app': True,
#    'ni': True,
#    'sebab': True,
#    'kena': True,
#    'banned': True,
#    'notis': True,
#    'masuk': True,
#    'tiba': True,
#    'padahal': True,
#    'ramai': True,
#    'kawan': True,
#    'dapat': True,
#    'kat': True,
#    'sini': True},
#   'Negative'),
#  ({'keep': True, 'banning': True, 'time': True}, 'Positive'),
#  ({'connecting': True,
#    'older': True,
#    'user': True,
#    'expensive': True,
#    'everything': True,
#    'price': True,
#    'use': True,
#    'cumbersome': True,
#    'communication': True,
#    'hanging': True,
#    'walmart': True,
#    'get': True,
#    'interaction': True,
#    'even': True,
#    'posting': True,
#    'review': True,
#    'proving': True,
#    'difficult': True},
#   'Negative'),
#  ({'trying': True,
#    'purchase': True,
#    'plan': True,
#    'keep': True,
#    'getting': True,
#    'error': True,
#    'saying': True,
#    'something': True,
#    'went': True,
#    'wrong': True,
#    'please': True,
#    'try': True,
#    'tried': True,
#    'deleting': True,
#    'app': True,
#    'reinstall': True,
#    'restart': True,
#    'phone': True,
#    'wifi': True,
#    'even': True,
#    'deleted': True,
#    'profile': True,
#    'started': True},
#   'Negative'),
#  ({'good': True, 'app': True}, 'Positive'),
#  ({'fun': True,
#    'fact': True,
#    'gennemsnitlige': True,
#    'pige': True,
#    'f': True,
#    'r': True,
#    'omtrent': True,
#    'like': True,
#    'dagligt': True,
#    'men': True,
#    'mand': True},
#   'Positive'),
#  ({'update': True,
#    'prompt': True,
#    'profile': True,
#    'review': True,
#    'take': True,
#    'minute': True,
#    'hr': True,
#    'later': True,
#    'uninstalled': True,
#    'reinstalled': True,
#    'time': True,
#    'helping': True},
#   'Negative'),
#  ({'cool': True}, 'Positive'),
#  ({'app': True, 'glitch': True, 'lot': True}, 'Positive'),
#  ({'good': True}, 'Positive'),
#  ({'bot': True, 'r': True, 'match': True}, 'Positive'),
#  ({'good': True, 'app': True}, 'Positive'),
#  ({'tinder': True,
#    'went': True,
#    'full': True,
#    'crazy': True,
#    'annual': True,
#    'membership': True,
#    'used': True,
#    'around': True,
#    'pretty': True,
#    'high': True,
#    'dating': True,
#    'app': True,
#    'considering': True,
#    'many': True,
#    'free': True,
#    'option': True,
#    'raise': True,
#    'people': True,
#    'tripping': True},
#   'Negative'),
#  ...]

# %%
split_index = int(len(dataset) * 0.7)
train_data = dataset[:split_index]
test_data = dataset[split_index:]

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_data)

print(" Training Accuracy is:", round(classify.accuracy(classifier, train_data),2)*100)

print("Testing Accuracy is:", round(classify.accuracy(classifier, test_data),2)*100)

print(classifier.show_most_informative_features(10))
#COME BACK
# Out:
#  Training Accuracy is: 74.0
# Testing Accuracy is: 73.0
# Most Informative Features
#                     poor = True           Negati : Positi =     90.7 : 1.0
#                excellent = True           Positi : Negati =     70.3 : 1.0
#              explanation = True           Negati : Positi =     64.6 : 1.0
#                     hate = True           Negati : Positi =     59.5 : 1.0
#                    wrong = True           Negati : Positi =     50.3 : 1.0
#                    false = True           Negati : Positi =     42.6 : 1.0
#                   failed = True           Negati : Positi =     38.7 : 1.0
#                 reported = True           Negati : Positi =     35.7 : 1.0
#               ridiculous = True           Negati : Positi =     34.2 : 1.0
#                 canceled = True           Negati : Positi =     33.3 : 1.0
# None

# %% [markdown]
# # TFIDF for sentiment analysis :

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
vector = tfidf.fit_transform(data_cleaned['content'])
y = data_cleaned['sentiment']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(vector,
                                                    y,
                                                    test_size=0.33,
                                                    random_state=42,
                                                    stratify = y)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression

# %%
def metrics(y_train,y_train_pred,y_test,y_test_pred):
  print("training accuracy = ",round(accuracy_score(y_train,y_train_pred),2)*100)
  ConfusionMatrixDisplay.from_predictions(y_train,y_train_pred,normalize = 'all')
  print(classification_report(y_train,y_train_pred))
  plt.show()

  print("testing accuracy = ",round(accuracy_score(y_test,y_test_pred),2)*100)
  ConfusionMatrixDisplay.from_predictions(y_test,y_test_pred,normalize = 'all')
  print(classification_report(y_test,y_test_pred))
  plt.show()

# %% [markdown]
# # MULTINOMIAL NB

# %%
NB = MultinomialNB()
NB.fit(X_train,y_train)
y_train_pred = NB.predict(X_train)
y_test_pred = NB.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  86.0
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85      8026
#            1       0.95      0.79      0.86     10073
#
#     accuracy                           0.86     18099
#    macro avg       0.86      0.87      0.86     18099
# weighted avg       0.87      0.86      0.86     18099
# testing accuracy =  83.0
#               precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82      3953
#            1       0.92      0.76      0.83      4962
#
#     accuracy                           0.83      8915
#    macro avg       0.83      0.84      0.83      8915
# weighted avg       0.84      0.83      0.83      8915

# %% [markdown]
# # LINEAR SVC

# %%
svc = LinearSVC()
svc.fit(X_train,y_train)
y_train_pred = svc.predict(X_train)
y_test_pred = svc.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  94.0
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94      8026
#            1       0.96      0.94      0.95     10073
#
#     accuracy                           0.94     18099
#    macro avg       0.94      0.94      0.94     18099
# weighted avg       0.94      0.94      0.94     18099
# testing accuracy =  86.0
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84      3953
#            1       0.87      0.88      0.87      4962
#
#     accuracy                           0.86      8915
#    macro avg       0.85      0.85      0.85      8915
# weighted avg       0.86      0.86      0.86      8915

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  89.0
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      8026
#            1       0.91      0.89      0.90     10073
#
#     accuracy                           0.89     18099
#    macro avg       0.89      0.89      0.89     18099
# weighted avg       0.89      0.89      0.89     18099
# testing accuracy =  86.0
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.84      3953
#            1       0.87      0.87      0.87      4962
#
#     accuracy                           0.86      8915
#    macro avg       0.85      0.85      0.85      8915
# weighted avg       0.86      0.86      0.86      8915

# %% [markdown]
# # Storing the model in hopsworks

# %%
import numpy as np

# Convert X_train to a dense numpy array
if isinstance(X_train, np.ndarray) == False:
    X_train = X_train.toarray()

if isinstance(X_test, np.ndarray) == False:
    X_test = X_test.toarray()

# %%
import os
import joblib
from hsml.schema import Schema
from hsml.model_schema import ModelSchema

# Create a directory for the model artifacts if it doesn't exist
model_dir = "linear_svc_model"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)

# Save the LinearSVC model using joblib
joblib.dump(svc, f"{model_dir}/model.pkl")
print("Model saved as model.pkl")

# Creating input and output schemas using the 'Schema' class for features (X) and target variable (y)
input_schema = Schema(X_train)
output_schema = Schema(y_train)

# Creating a model schema using 'ModelSchema' with the input and output schemas
model_schema = ModelSchema(input_schema=input_schema, output_schema=output_schema)

# Define metrics (replace with your actual metrics)
res_dict = {
    "Accuracy": str(round(accuracy_score(y_test, svc.predict(X_test)), 4)),
}

# Access the model registry
mr = project.get_model_registry()

# Create the model in the model registry
svc_model = mr.python.create_model(
    name="linear_svc_model",
    metrics=res_dict,
    model_schema=model_schema,
    input_example=X_test[np.random.choice(X_test.shape[0], 1)],  # Provide an example input
    description="Sentiment analysis with LinearSVC",
)

# Save the model artifacts to the model registry
svc_model.save(model_dir)
print(f"Model saved successfully! Explore it at {svc_model.get_url()}")
# Out:
# Model saved as model.pkl
#   0%|          | 0/6 [00:00<?, ?it/s]
# Uploading: 0.000%|          | 0/120779 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/75380 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/239 elapsed<00:00 remaining<?
# Model created, explore it at https://c.app.hopsworks.ai:443/p/1185941/models/linear_svc_model/1
# Model saved successfully! Explore it at https://c.app.hopsworks.ai:443/p/1185941/models/linear_svc_model/1

# %%
model_dir = "vectorizer"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
joblib.dump(tfidf, f"{model_dir}/vectorizer.pkl")
# Access the model registry
mr = project.get_model_registry()

# Create the model in the model registry
vectorizer_model = mr.python.create_model(
    name="vectorizer",
    #metrics=res_dict,
    #model_schema=model_schema,
    #input_example=X_test[np.random.choice(X_test.shape[0], 1)],  # Provide an example input
    description="Vectorizer for LinearSVC",
)
vectorizer_model.save(model_dir)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Uploading: 0.000%|          | 0/310416 elapsed<00:00 remaining<?
# Model created, explore it at https://c.app.hopsworks.ai:443/p/1185941/models/vectorizer/1
# Model(name: 'vectorizer', version: 1)

# %%
print(len(tfidf.vocabulary_))
# Out:
# 15006
